# %%
import pandas as pd
import seaborn as sns
import google.colab as files

# %%
df_2017 = pd.read_csv('data20152019.csv', sep= ';', encoding='cp1251')
df_2017 = df_2017.iloc[35:43, :]

# %%
df_2017 = pd.DataFrame(df_2017, columns= ['Субъект РФ','Численность студентов, очная форма, человек, 2017'])
df_2017
# Out:
#                              Субъект РФ  \
# 35                   Краснодарский край
# 36                 Астраханская область
# 37                Волгоградская область
# 38                   Ростовская область
# 39                        г.Севастополь
# 40                      Республика Крым
# 41  Северо-Кавказский федеральный округ
# 42                  Республика Дагестан
#
#     Численность студентов, очная форма, человек, 2017
# 35                                              58855
# 36                                              16685
# 37                                              33513
# 38                                              69521
# 39                                               8627
# 40                                              25550
# 41                                             107650
# 42                                              26289

# %%
plot = sns.barplot(df_2017, x = 'Субъект РФ', y = 'Численность студентов, очная форма, человек, 2017')
plot.set_xticklabels(labels = df_2017['Субъект РФ'], rotation = 90)
# Out:
# [Text(0, 0, '   Краснодарский край'),
#  Text(1, 0, '   Астраханская область'),
#  Text(2, 0, '   Волгоградская область'),
#  Text(3, 0, '   Ростовская область'),
#  Text(4, 0, '   г.Севастополь'),
#  Text(5, 0, '   Республика Крым'),
#  Text(6, 0, 'Северо-Кавказский федеральный округ'),
#  Text(7, 0, '   Республика Дагестан')]

# %%
df_2017.to_csv('data2017.cvs')
