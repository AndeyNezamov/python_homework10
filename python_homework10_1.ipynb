# %%
import pandas as pd
import google.colab as files

# %%
df_2015 = pd.read_csv('data20152019.csv', sep= ';', encoding='cp1251')
df_2015 = df_2015.iloc[4:22, :]

# %%
df_2015 = pd.DataFrame(df_2015, columns= ['Субъект РФ','Численность студентов очно-заочная (вечерняя) форма, человек, 2015'])

# %%
max_value = df_2015['Численность студентов очно-заочная (вечерняя) форма, человек, 2015'].max()
df_2015[df_2015['Численность студентов очно-заочная (вечерняя) форма, человек, 2015'] == max_value]
# Out:
#      Субъект РФ  \
# 19     г.Москва
#
#     Численность студентов очно-заочная (вечерняя) форма, человек, 2015
# 19                                              57709

# %%
df_2015.to_csv('data2015.cvs')
files.files.download('data2015.cvs')
